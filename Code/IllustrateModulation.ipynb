# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from panoradio_hf.simulation import BPSKGenerator, QPSKGenerator
from panoradio_hf.analysis import compare_modulations

# %%
bpsk_gen = BPSKGenerator(13)
qpsk_gen = QPSKGenerator(13)

nsymbols = 512
bpsk_signal = bpsk_gen(nsymbols)
qpsk_signal = qpsk_gen(nsymbols)

# %%
compare_modulations(bpsk_signal,
                    qpsk_signal)
